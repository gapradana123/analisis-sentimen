# %% [markdown]
# Nama     : Gregorius Adi Pradana
#
# Username : gapradana123
#
# Email    : gapradana123@gmail.com

# %% [markdown]
# # Instal dan Import Library

# %%
# !pip install google-play-scraper

# %%
from google_play_scraper import reviews, Sort
import pandas as pd

# %% [markdown]
# # Scrapping

# %%
# Mengambil semua ulasan dari aplikasi 'mytelkomsel di Google Play Store.
scrapreview, continuation_token = reviews(
    'com.telkomsel.telkomselcm', # ID aplikasi 'mytelkomsel'
    lang='id',                   # Ulasan dengan bahasa indonesia
    country='id',                # Negara Indonesia
    sort=Sort.NEWEST,            # Urutan ulasan mulai dari yang paling baru
    count=100000                  # Ambil 100000 ulasan terbaru
)

# %%
# Membuat dataframe dari hasil scrapping
app_reviews_df = pd.DataFrame(scrapreview)
# Menampilkan informasi tentang DataFrame app_reviews_df
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              100000 non-null  object
#  1   userName              100000 non-null  object
#  2   userImage             100000 non-null  object
#  3   content               100000 non-null  object
#  4   score                 100000 non-null  int64
#  5   thumbsUpCount         100000 non-null  int64
#  6   reviewCreatedVersion  82287 non-null   object
#  7   at                    100000 non-null  datetime64[ns]
#  8   replyContent          87756 non-null   object
#  9   repliedAt             87756 non-null   datetime64[ns]
#  10  appVersion            82287 non-null   object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 8.4+ MB

# %%
# Memilih kolom yang digunakan
app_reviews_df = app_reviews_df[['content', 'score']]
# Membuat DataFrame baru (clean_df) dengan menghapus baris yang memiliki nilai yang hilang (NaN) dari app_reviews_df
clean_df = app_reviews_df.dropna()
# Menghapus baris duplikat dari DataFrame clean_df
clean_df = clean_df.drop_duplicates()
# Reset index
clean_df = clean_df.reset_index(drop=True)
# Menampilkan informasi tentang DataFrame clean_df setelah membersihkan nilai yang hilang (NaN) dan duplikat
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80810 entries, 0 to 80809
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  80810 non-null  object
#  1   score    80810 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 1.2+ MB

# %%
pd.set_option('display.max_colwidth', 3000)
# Menampilkan dataframe
clean_df
# Out:
#                                                                                                                             content  \
# 0                                                                           Kenapa ngga bisa kirim hadiah untuk paket orbit lagi ya
# 1                                                                           Nyesel gw ganti ke Telkomsel,sinyalnya gk sebagus Axis.
# 2                                                                                       sinyal gangguan terus jadi ganggu main game
# 3                                                                                                                             Keren
# 4                                                                                       Tolong jaringan diperbaiki lagi ke depannya
# ...                                                                                                                             ...
# ...

# %%
# Menyimpan hasil scrapping dalam bentuk csv
clean_df.to_csv('ulasan_aplikasi_mytelkomsel.csv', index=False)
